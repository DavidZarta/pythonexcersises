# %%
import matplotlib.pyplot as plt

plt.plot([1,2,3,4],[5,6,7,8])
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1,3,4],[5,6,8])
plt.show()
